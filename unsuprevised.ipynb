# %% [markdown]
# <a href="https://colab.research.google.com/github/gangwarrishabh045-ui/Ml-Projects-1/blob/main/unsuprevised.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import KMeans

# Training data
x = [[20], [30], [40], [50], [60], [60]]

# Choose clusters less than or equal to number of samples
model = KMeans(n_clusters=4)  # try 2 clusters

# Fit the model
model.fit(x)

# Predict cluster for 60
print(model.predict([[60]]))
# Out:
# [0]
