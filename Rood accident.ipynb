# %% [markdown]
# <a href="https://colab.research.google.com/github/gangwarrishabh045-ui/Ml-Projects-1/blob/main/Rood%20accident.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
df = pd.read_csv(r"C:\Users\pintu\OneDrive\Desktop\classpractice\class_assignment\cleaned.csv")
print(df.columns)
print(df.head())
df_encoded = pd.get_dummies(df['Type_of_collision'], drop_first=True)
X = df_encoded
y = df['Accident_severity']
# Train model
model = LinearRegression()
model.fit(X, y)
# Prediction
y_pred = model.predict(X)
# Plot
plt.figure(figsize=(8,5))
plt.scatter(range(len(y)), y, label="Actual Severity")
plt.plot(range(len(y)), y_pred, color='red', label="Predicted Line")
plt.xlabel("Samples")
plt.ylabel("Accident Severity")
plt.title("Accident Severity Prediction")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_173/431199909.py in <cell line: 0>()
#       2 import matplotlib.pyplot as plt
#       3 from sklearn.linear_model import LinearRegression
# ----> 4 df = pd.read_csv(r"C:\Users\pintu\OneDrive\Desktop\classpractice\class_assignment\cleaned.csv")
#       5 print(df.columns)
#       6 print(df.head())
#
# ...

# %% [markdown]
# ### How to Upload Your `cleaned.csv` File to Colab
#
# There are two main ways to make your file accessible in Google Colab:
#
# 1.  **Upload Directly to Colab Session (Temporary):**
#     *   Run the Python code below. It will prompt you to choose a file from your local computer.
#     *   This method is temporary; the file will be deleted when your Colab session ends.
#
# 2.  **Mount Google Drive (Persistent):**
#     *   If your file is in Google Drive, you can mount your Drive to Colab.
#     *   Run `from google.colab import drive; drive.mount('/content/drive')`.
#     *   Then, you can access your file using a path like `/content/drive/My Drive/path/to/your/cleaned.csv`.
#
# Please choose one of these methods and then re-run the cell with `pd.read_csv`.

# %%
from google.colab import files

# This will open a file selection dialog in your browser
# Select your 'cleaned.csv' file from your local machine
uploaded = files.upload()

for fn in uploaded.keys():
  print(f'User uploaded file "{fn}" with length {len(uploaded[fn])} bytes')

# After uploading, the file will be in the current working directory, e.g., '/content/cleaned.csv'
